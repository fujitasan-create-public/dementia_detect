# %% [markdown]
# # EDA: DementiaBank 英語データの特徴分布確認
#
# raw（英語）データを読み込み、ラベル分布・特徴量分布・t-SNE可視化を行う。

# %%
import sys; sys.path.insert(0, '..')
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.manifold import TSNE
from src.preprocessing.data_loader import load_dialogues

# %%
dialogues = load_dialogues(source='raw')
print(f'total: {len(dialogues)}')
labels = [d.label for d in dialogues]
pd.Series(labels).value_counts().plot(kind='bar', title='Label Distribution')

# %% [markdown]
# ## t-SNE による特徴空間の可視化
#
# 特徴量 CSV が生成された後に実行する。

# %%
# features_csv = '../data/processed/features.csv'
# df = pd.read_csv(features_csv)
# X = df.drop(columns=['label']).fillna(0).values
# y = df['label'].values
# tsne = TSNE(n_components=2, random_state=42)
# emb = tsne.fit_transform(X)
# plt.scatter(emb[:, 0], emb[:, 1], c=y, cmap='bwr', alpha=0.6)
# plt.title('t-SNE of feature space')
# plt.show()
